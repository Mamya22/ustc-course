# %%
import pandas as pd
import numpy as np
df = pd.read_csv("data//output_relax.csv",encoding="utf-8")
df = np.array(df)
df = df.tolist()
print(df)
# Out:
# [[5.0, 30162.0, 8.0, 10.64, 0.73], [10.0, 30162.0, 8.0, 15.85, 0.44], [15.0, 30162.0, 8.0, 18.74, 0.38], [20.0, 30162.0, 8.0, 22.32, 0.3], [25.0, 30162.0, 8.0, 22.32, 0.34], [30.0, 30162.0, 8.0, 30.07, 0.24], [35.0, 30162.0, 8.0, 30.07, 0.25], [40.0, 30162.0, 8.0, 30.07, 0.24], [45.0, 30162.0, 8.0, 30.07, 0.24], [50.0, 30162.0, 8.0, 30.07, 0.24], [55.0, 30162.0, 8.0, 30.07, 0.23], [60.0, 30162.0, 8.0, 38.94, 0.19], [65.0, 30162.0, 8.0, 38.94, 0.19], [70.0, 30162.0, 8.0, 38.94, 0.18], [75.0, 30162.0, 8.0, 38.94, 0.18], [80.0, 30162.0, 8.0, 38.94, 0.19], [85.0, 30162.0, 8.0, 38.94, 0.18], [90.0, 30162.0, 8.0, 38.94, 0.19], [95.0, 30162.0, 8.0, 38.94, 0.19], [100.0, 30162.0, 8.0, 38.94, 0.18], [10.0, 30162.0, 8.0, 15.85, 0.45], [10.0, 30162.0, 7.0, 14.1, 0.41], [10.0, 30162.0, 6.0, 11.8, 0.37], [10.0, 30162.0, 5.0, 10.3, 0.32], [10.0, 30162.0, 4.0, 5.34, 0.31], [10.0, 30162.0, 3.0, 2.88, 0.23], [10.0, 30162.0, 2.0, 0.68, 0.17], [10.0, 30162.0, 1.0, 0.04, 0.1], [10.0, 5000.0, 8.0, 23.96,
# ...

# %%
df5 = pd.read_csv("data//output_str.csv",encoding="utf-8")
df5
# Out:
#        K  DataSize  qi    NCP  Running Time
# 0      5     30162   8   8.30          0.69
# 1     10     30162   8  11.24          0.47
# 2     15     30162   8  13.24          0.39
# 3     20     30162   8  15.03          0.35
# 4     25     30162   8  16.35          0.31
# ..   ...       ...  ..    ...           ...
# 131   96     30162   8  29.96          0.21
# 132   97     30162   8  29.96          0.21
# 133   98     30162   8  30.04          0.20
# 134   99     30162   8  30.11          0.21
# 135  100     30162   8  30.09          0.21
#
# [136 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

a = []
b = []
c = []


for i in range(4994,5093):
    # print(i)
    if df[i][1] == 30162.0 and df[i][2] == 8.0:
        a.append(df[i][0])
        b.append(df[i][3])
        c.append(df[i][4])

plt.figure(figsize=(10,10),)
plt.scatter(a, b)
plt.xlabel("K")
plt.ylabel("NCP/GCP")
plt.show()

# %%
import matplotlib.pyplot as plt

a = []
b = []
c = []


for i in range(145, 152, 1):
    # print(i)
    # if df[i][1] == 30162.0 and df[i][2] == 8.0:
    a.append(df[i][1])
    b.append(df[i][3])
    c.append(df[i][4])

plt.figure(figsize=(5,5),)
plt.scatter(a, b)
plt.xlabel("DataSize")
plt.ylabel("NCP/GCP")
plt.show()

# %%
import matplotlib.pyplot as plt

a = []
b = []
c = []


for i in range(34, 42, 1):
    # print(i)
    # if df[i][1] == 30162.0 and df[i][2] == 8.0:
    a.append(df[i][2])
    b.append(df[i][3])
    c.append(df[i][4])

plt.figure(figsize=(5,5),)
plt.scatter(a, b)
plt.xlabel("qi")
plt.ylabel("NCP/GCP")
plt.show()

# %%
dfs = pd.read_csv("data//output_strict.csv",encoding="utf-8")
print(dfs)
# Out:
#       K  DataSize  qi    NCP  Running Time
# 0     5     30162   8   8.30          0.69
# 1    10     30162   8  11.24          0.47
# 2    15     30162   8  13.24          0.39
# 3    20     30162   8  15.03          0.35
# 4    25     30162   8  16.35          0.31
# 5    30     30162   8  17.59          0.29
# 6    35     30162   8  18.61          0.29
# 7    40     30162   8  19.66          0.27
# 8    45     30162   8  21.02          0.25
# 9    50     30162   8  22.16          0.25
# 10   55     30162   8  23.13          0.26
# 11   60     30162   8  23.66          0.23
# 12   65     30162   8  24.52          0.23
# 13   70     30162   8  25.30          0.24
# 14   75     30162   8  26.38          0.22
# 15   80     30162   8  27.26          0.22
# 16   85     30162   8  28.00          0.21
# 17   90     30162   8  29.46          0.22
# 18   95     30162   8  29.83          0.21
# 19  100     30162   8  30.09          0.21
# 20   10     30162   8  11.24          0.49
# ...

# %%
df2 = pd.read_csv("data//output_2.csv",encoding="utf-8")
print(df2)
# Out:
#       K  DataSize  qi    NCP  Running Time
# 0     2     30162   8   7.84          2.01
# 1     2     30162   8   7.84          2.01
# 2     5     30162   8  19.84          2.02
# 3     2     30162   8   7.84          2.01
# 4     5     30162   8  19.84          2.02
# 5    10     30162   8  28.56          2.01
# 6     2     30162   8   7.84          2.01
# 7     5     30162   8  19.84          2.02
# 8    10     30162   8  28.56          2.01
# 9    25     30162   8  36.69          1.91
# 10    2     30162   8   7.84          2.01
# 11    5     30162   8  19.84          2.02
# 12   10     30162   8  28.56          2.01
# 13   25     30162   8  36.69          1.91
# 14   50     30162   8  45.21          1.75
# 15    2     30162   8   7.84          2.01
# 16    5     30162   8  19.84          2.02
# 17   10     30162   8  28.56          2.01
# 18   25     30162   8  36.69          1.91
# 19   50     30162   8  45.21          1.75
# 20  100     30162   8  51.17          1.64
# ...

# %%
df[['']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 relax = df.tolist()
#
# File d:\anaconda\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'tolist'
